# %%
import pandas as pd
adult=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data")

# %%
adult.head(5)
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult.columns=adult.columns.str.replace(' ',"")

# %%
adult.head(2)
# Out:
#    39          State-gov   77516   Bachelors  13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 1  38            Private  215646     HS-grad   9             Divorced
#
#          Adm-clerical   Not-in-family   White   Male  2174  0  40  \
# 0     Exec-managerial         Husband   White   Male     0  0  13
# 1   Handlers-cleaners   Not-in-family   White   Male     0  0  40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K

# %%
clean_adult=adult.drop(["13","2174","77516","0","40"],axis=1)

# %%
clean_adult
# Out:
#        39          State-gov    Bachelors        Never-married  \
# 0      50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1      38            Private      HS-grad             Divorced
# 2      53            Private         11th   Married-civ-spouse
# 3      28            Private    Bachelors   Married-civ-spouse
# 4      37            Private      Masters   Married-civ-spouse
# ...    ..                ...          ...                  ...
# 32555  27            Private   Assoc-acdm   Married-civ-spouse
# 32556  40            Private      HS-grad   Married-civ-spouse
# 32557  58            Private      HS-grad              Widowed
# 32558  22            Private      HS-grad        Never-married
# 32559  52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   United-States  \
# 0         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
clean_adult.head(2)
# Out:
#    39          State-gov   Bachelors        Never-married        Adm-clerical  \
# 0  50   Self-emp-not-inc   Bachelors   Married-civ-spouse     Exec-managerial
# 1  38            Private     HS-grad             Divorced   Handlers-cleaners
#
#     Not-in-family   White   Male   United-States   <=50K
# 0         Husband   White   Male   United-States   <=50K
# 1   Not-in-family   White   Male   United-States   <=50K

# %%
clean_adult["<=50K"]=clean_adult["<=50K"].str.replace("<=50K","50k")

# %%
clean_adult.head(2)
# Out:
#    Age          State-gov   Bachelors        Never-married  \
# 0   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 1   38            Private     HS-grad             Divorced
#
#          Adm-clerical   Not-in-family   White   Male   United-States <=50K
# 0     Exec-managerial         Husband   White   Male   United-States   50k
# 1   Handlers-cleaners   Not-in-family   White   Male   United-States   50k

# %%
clean_adult.columns=clean_adult.columns.str.replace("39","Age")

# %%
clean_adult
# Out:
#        Age          State-gov    Bachelors        Never-married  \
# 0       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1       38            Private      HS-grad             Divorced
# 2       53            Private         11th   Married-civ-spouse
# 3       28            Private    Bachelors   Married-civ-spouse
# 4       37            Private      Masters   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32555   27            Private   Assoc-acdm   Married-civ-spouse
# 32556   40            Private      HS-grad   Married-civ-spouse
# 32557   58            Private      HS-grad              Widowed
# 32558   22            Private      HS-grad        Never-married
# 32559   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   United-States  \
# 0         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
clean_adult["<=50K"]=clean_adult["<=50K"].str.replace("K","000")

# %%
clean_adult.head(2)
# Out:
#    Age          State-gov   Bachelors        Never-married  \
# 0   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 1   38            Private     HS-grad             Divorced
#
#          Adm-clerical   Not-in-family   White   Male   United-States <=50K
# 0     Exec-managerial         Husband   White   Male   United-States   50k
# 1   Handlers-cleaners   Not-in-family   White   Male   United-States   50k

# %%
clean_adult.columns=clean_adult.columns.str.replace("<=50K","salary")

# %%
clean_adult
# Out:
#        Age          State-gov    Bachelors        Never-married  \
# 0       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1       38            Private      HS-grad             Divorced
# 2       53            Private         11th   Married-civ-spouse
# 3       28            Private    Bachelors   Married-civ-spouse
# 4       37            Private      Masters   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32555   27            Private   Assoc-acdm   Married-civ-spouse
# 32556   40            Private      HS-grad   Married-civ-spouse
# 32557   58            Private      HS-grad              Widowed
# 32558   22            Private      HS-grad        Never-married
# 32559   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   United-States  \
# 0         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
clean_adult["salary"]=clean_adult["salary"].str.replace(">50000","50k")

# %%
clean_adult["salary"]
# Out:
# 0         50k
# 1         50k
# 2         50k
# 3         50k
# 4         50k
#          ...
# 32555     50k
# 32556     50k
# 32557     50k
# 32558     50k
# 32559     50k
# Name: salary, Length: 32560, dtype: object

# %%
clean_adult["salary"]=clean_adult["salary"].str.replace("k","000")

# %%
clean_adult["salary"]
# Out:
# 0         50000
# 1         50000
# 2         50000
# 3         50000
# 4         50000
#           ...
# 32555     50000
# 32556     50000
# 32557     50000
# 32558     50000
# 32559     50000
# Name: salary, Length: 32560, dtype: object

# %%
clean_adult.head(2)
# Out:
#    Age          State-gov   Bachelors        Never-married  \
# 0   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 1   38            Private     HS-grad             Divorced
#
#          Adm-clerical   Not-in-family   White   Male   United-States  salary
# 0     Exec-managerial         Husband   White   Male   United-States   50000
# 1   Handlers-cleaners   Not-in-family   White   Male   United-States   50000

# %%
clean_adult.columns=clean_adult.columns.str.replace("Male","Sex")

# %%
clean_adult.head(2)
# Out:
#    Age          State-gov   Bachelors        Never-married  \
# 0   50   Self-emp-not-inc   Bachelors   Married-civ-spouse
# 1   38            Private     HS-grad             Divorced
#
#          Adm-clerical   Not-in-family   White    Sex   United-States  salary
# 0     Exec-managerial         Husband   White   Male   United-States   50000
# 1   Handlers-cleaners   Not-in-family   White   Male   United-States   50000

# %%
clean_adult["Sex"]
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3         Female
# 4         Female
#           ...
# 32555     Female
# 32556       Male
# 32557     Female
# 32558       Male
# 32559     Female
# Name: Sex, Length: 32560, dtype: object

# %%
clean_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            32560 non-null  int64
#  1   State-gov      32560 non-null  object
#  2   Bachelors      32560 non-null  object
#  3   Never-married  32560 non-null  object
#  4   Adm-clerical   32560 non-null  object
#  5   Not-in-family  32560 non-null  object
#  6   White          32560 non-null  object
#  7   Sex            32560 non-null  object
#  8   United-States  32560 non-null  object
#  9   salary         32560 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB

# %%
clean_adult["Age"]=clean_adult["Age"].astype("int")
clean_adult["salary"]=clean_adult["salary"].astype("int")

# %%
clean_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            32560 non-null  int64
#  1   State-gov      32560 non-null  object
#  2   Bachelors      32560 non-null  object
#  3   Never-married  32560 non-null  object
#  4   Adm-clerical   32560 non-null  object
#  5   Not-in-family  32560 non-null  object
#  6   White          32560 non-null  object
#  7   Sex            32560 non-null  object
#  8   United-States  32560 non-null  object
#  9   salary         32560 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 2.5+ MB

# %%
clean_adult
# Out:
#        Age          State-gov    Bachelors        Never-married  \
# 0       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1       38            Private      HS-grad             Divorced
# 2       53            Private         11th   Married-civ-spouse
# 3       28            Private    Bachelors   Married-civ-spouse
# 4       37            Private      Masters   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32555   27            Private   Assoc-acdm   Married-civ-spouse
# 32556   40            Private      HS-grad   Married-civ-spouse
# 32557   58            Private      HS-grad              Widowed
# 32558   22            Private      HS-grad        Never-married
# 32559   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White      Sex   United-States  \
# 0         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
clean_adult[clean_adult.duplicated()]
# Out:
#        Age State-gov      Bachelors        Never-married        Adm-clerical  \
# 351     33   Private      Bachelors   Married-civ-spouse     Exec-managerial
# 370     17   Private           11th        Never-married       Other-service
# 375     33   Private        HS-grad   Married-civ-spouse        Craft-repair
# 390     27   Private      Bachelors        Never-married        Craft-repair
# 434     33   Private        Masters   Married-civ-spouse      Prof-specialty
# ...    ...       ...            ...                  ...                 ...
# 32551   43   Private      Assoc-voc   Married-civ-spouse               Sales
# 32553   53   Private        Masters   Married-civ-spouse     Exec-managerial
# 32554   22   Private   Some-college        Never-married     Protective-serv
# 32556   40   Private        HS-grad   Married-civ-spouse   Machine-op-inspct
# 32558   22   Private        HS-grad        Never-married        Adm-clerical
#
# ...

# %%
clean_adult.to_csv("uci_adult_clear.csv",index=False)

# %%
clean_adult.columns=clean_adult.columns.str.replace("White","Colour")
clean_adult.columns=clean_adult.columns.str.replace("United-States","Country")
clean_adult.columns=clean_adult.columns.str.replace("State-gov","Job")
clean_adult.columns=clean_adult.columns.str.replace("Bachelors","Degress")
clean_adult.columns=clean_adult.columns.str.replace("Never-married","Marriage_Status")
clean_adult.columns=clean_adult.columns.str.replace("Adm-clerical","Job_post")

# %%
clean_adult
# Out:
#        Age                Job      Degress      Marriage_Status  \
# 0       50   Self-emp-not-inc    Bachelors   Married-civ-spouse
# 1       38            Private      HS-grad             Divorced
# 2       53            Private         11th   Married-civ-spouse
# 3       28            Private    Bachelors   Married-civ-spouse
# 4       37            Private      Masters   Married-civ-spouse
# ...    ...                ...          ...                  ...
# 32555   27            Private   Assoc-acdm   Married-civ-spouse
# 32556   40            Private      HS-grad   Married-civ-spouse
# 32557   58            Private      HS-grad              Widowed
# 32558   22            Private      HS-grad        Never-married
# 32559   52       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                  Job_post   Not-in-family  Colour      Sex         Country  \
# 0         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
clean_adult.to_csv("uci_adult_clear.csv",index=False)
